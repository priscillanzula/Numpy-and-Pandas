# %%
import os

# %% [markdown]
# The os module in Python provides many functions for interacting with the OS and the filesystem.

# %%
# checking present working directory
os.getcwd()
# Out:
# 'C:\\Users\\priscillah\\documents\\Portfolio_projects\\analytics'

# %%
# to get the list if the files in a directory 
os.listdir('.') # relative path
# Out:
# ['.ipynb_checkpoints', 'General.ipynb', 'Read_Write_files.ipynb']

# %%
os.listdir('/Users')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'priscillah', 'Public']

# %%
# making a new directory 
os.makedirs('./data_analytics', exist_ok=True )

# %%
# verify the new folder creation
os.listdir('./data_analytics')
# Out:
# []

# %%
'data_analytics' in os.listdir('.')
# Out:
# True

# %%
# Using urlLib Module, download data int our new folder directory
# Given below urls


url_train = "https://github.com/shrikant-temburwar/Loan-Prediction-Dataset/raw/master/train.csv"
url_test = "https://github.com/shrikant-temburwar/Loan-Prediction-Dataset/raw/master/test.csv"
url_credit = "https://github.com/FelixCharotte/LoanApprovalPrediction_KaggleCompetition/raw/main/data/credit_risk_dataset.csv"

# %%
import urllib.request

# %%
urllib.request.urlretrieve(url_train, "./data_analytics/loan_train.csv")
urllib.request.urlretrieve(url_test, "./data_analytics/loan_test.csv")
urllib.request.urlretrieve(url_credit, "./data_analytics/credit_risk.csv")
# Out:
# ('./data_analytics/credit_risk.csv',
#  <http.client.HTTPMessage at 0x22eb0164a60>)

# %%
#Let's verify that the files were downloaded.

os.listdir('./data_analytics')
# Out:
# ['credit_risk.csv', 'loan_test.csv', 'loan_train.csv']

# %% [markdown]
# ### Reading from a file

# %% [markdown]
# To read the contents of a file, we first need to open the file using the built-in open function. The
# open function returns a file object, provides several methods for interacting with the contents of
# the file. It also accepts a mode argument

# %%
filel = open('./data_analytics/loan_test.csv', mode='r')

# %% [markdown]
# The open function also accepts a mode argument to specifies how we can interact with the file.
# The following options are supported:
# Character Meaning
#
# - 'r' - open for reading (default).
# - 'w' -open for writing, truncating the file first.
# - 'x' - create a new file and open it for writing .
# - 'a' - open for writing, appending to the end of the file if it exists.
# - 'b' -binary mode.
# - 't' - text mode (default).
# - '+' - open a disk file for updating (reading and writing).
# - 'U' - universal newline mode (deprecated).

# %% [markdown]
# - To get or read the contents of the filr we use Read function or method

# %%
file_content= filel.read()

# %%
print(file_content)
# Out:
# Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area
# LP001015,Male,Yes,0,Graduate,No,5720,0,110,360,1,Urban
# LP001022,Male,Yes,1,Graduate,No,3076,1500,126,360,1,Urban
# LP001031,Male,Yes,2,Graduate,No,5000,1800,208,360,1,Urban
# LP001035,Male,Yes,2,Graduate,No,2340,2546,100,360,,Urban
# LP001051,Male,No,0,Not Graduate,No,3276,0,78,360,1,Urban
# LP001054,Male,Yes,0,Not Graduate,Yes,2165,3422,152,360,1,Urban
# LP001055,Female,No,1,Not Graduate,No,2226,0,59,360,1,Semiurban
# LP001056,Male,Yes,2,Not Graduate,No,3881,0,147,360,0,Rural
# LP001059,Male,Yes,2,Graduate,,13633,0,280,240,1,Urban
# LP001067,Male,No,0,Not Graduate,No,2400,2400,123,360,1,Semiurban
# LP001078,Male,No,0,Not Graduate,No,3091,0,90,360,1,Urban
# LP001082,Male,Yes,1,Graduate,,2185,1516,162,360,1,Semiurban
# LP001083,Male,No,3+,Graduate,No,4166,0,40,180,,Urban
# LP001094,Male,Yes,2,Graduate,,12173,0,166,360,0,Semiurban
# ...

# %% [markdown]
# - Use close function to close a file. Once a file is closed it cannot be read.

# %%
filel.close()

# %%
filel.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 filel.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# - We can use with statement to close a file

# %%
with open('./data_analytics/loan_test.csv', 'r') as file2:
     file2_contents = file2.read()
     print(file2_contents)
# Out:
# Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area
# LP001015,Male,Yes,0,Graduate,No,5720,0,110,360,1,Urban
# LP001022,Male,Yes,1,Graduate,No,3076,1500,126,360,1,Urban
# LP001031,Male,Yes,2,Graduate,No,5000,1800,208,360,1,Urban
# LP001035,Male,Yes,2,Graduate,No,2340,2546,100,360,,Urban
# LP001051,Male,No,0,Not Graduate,No,3276,0,78,360,1,Urban
# LP001054,Male,Yes,0,Not Graduate,Yes,2165,3422,152,360,1,Urban
# LP001055,Female,No,1,Not Graduate,No,2226,0,59,360,1,Semiurban
# LP001056,Male,Yes,2,Not Graduate,No,3881,0,147,360,0,Rural
# LP001059,Male,Yes,2,Graduate,,13633,0,280,240,1,Urban
# LP001067,Male,No,0,Not Graduate,No,2400,2400,123,360,1,Semiurban
# LP001078,Male,No,0,Not Graduate,No,3091,0,90,360,1,Urban
# LP001082,Male,Yes,1,Graduate,,2185,1516,162,360,1,Semiurban
# LP001083,Male,No,3+,Graduate,No,4166,0,40,180,,Urban
# LP001094,Male,Yes,2,Graduate,,12173,0,166,360,0,Semiurban
# ...

# %%
file2.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 file2.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Redaing a file line by line

# %%
with open('./data_analytics/loan_train.csv', 'r') as file3:
     file3_contents = file3.readlines()

# %%
print(file3_contents)
# Out:
# ['Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area,Loan_Status\n', 'LP001002,Male,No,0,Graduate,No,5849,0,,360,1,Urban,Y\n', 'LP001003,Male,Yes,1,Graduate,No,4583,1508,128,360,1,Rural,N\n', 'LP001005,Male,Yes,0,Graduate,Yes,3000,0,66,360,1,Urban,Y\n', 'LP001006,Male,Yes,0,Not Graduate,No,2583,2358,120,360,1,Urban,Y\n', 'LP001008,Male,No,0,Graduate,No,6000,0,141,360,1,Urban,Y\n', 'LP001011,Male,Yes,2,Graduate,Yes,5417,4196,267,360,1,Urban,Y\n', 'LP001013,Male,Yes,0,Not Graduate,No,2333,1516,95,360,1,Urban,Y\n', 'LP001014,Male,Yes,3+,Graduate,No,3036,2504,158,360,0,Semiurban,N\n', 'LP001018,Male,Yes,2,Graduate,No,4006,1526,168,360,1,Urban,Y\n', 'LP001020,Male,Yes,1,Graduate,No,12841,10968,349,360,1,Semiurban,N\n', 'LP001024,Male,Yes,2,Graduate,No,3200,700,70,360,1,Urban,Y\n', 'LP001027,Male,Yes,2,Graduate,,2500,1840,109,360,1,Urban,Y\n', 'LP001028,Male,Yes,2,Graduate,No,3073,8106,200,360
# ...

# %% [markdown]
# ### Processing data from files

# %% [markdown]
# Before performing any operations on the data stored in a file, we need to convert the contents of
# the file from one large string into Python data types. For the file loans1.txt containing
# information about loans in a CSV format, we can do the following:
#
# - Read the file line by line
# - Parse the first line to get list of the column names or headers.
# - Split each remaining line and convert each value into its data type.
# - Create a dictionary for each loan using the headers as keys.
# - Create a list of dictionaries to keep track of all the loans.
#
# We define a function read_csv to do this. We'll also define some helper functions to build up the functionality step by
# step.
#
# Let's start by defining a function parse_header which takes a line as input and returns a list of
# column headers.

# %%
def parse_headers(header_line):
    return header_line.strip().split(',')

# %% [markdown]
# - The strip method removes any extra spaces and the newline character \n , and the split method breaks a string into a list using the given separator ( , in this case).

# %%
file3_contents[0]
# Out:
# 'Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area,Loan_Status\n'

# %%
headers = parse_headers(file3_contents[0])

# %%
headers
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
#lets get the values
def parse_values(data_line):
    values=[]
    for item in data_line.strip().split(','):
        values.append(item)
    return values

# %%
file3_contents[2]
# Out:
# 'LP001003,Male,Yes,1,Graduate,No,4583,1508,128,360,1,Rural,N\n'

# %%
file3_contents[2].strip().split(',')
# Out:
# ['LP001003',
#  'Male',
#  'Yes',
#  '1',
#  'Graduate',
#  'No',
#  '4583',
#  '1508',
#  '128',
#  '360',
#  '1',
#  'Rural',
#  'N']

# %%
parse_values(file3_contents[2])
# Out:
# ['LP001003',
#  'Male',
#  'Yes',
#  '1',
#  'Graduate',
#  'No',
#  '4583',
#  '1508',
#  '128',
#  '360',
#  '1',
#  'Rural',
#  'N']

# %%
values2= parse_values(file3_contents[2])

# %%
headers
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
values2
# Out:
# ['LP001003',
#  'Male',
#  'Yes',
#  '1',
#  'Graduate',
#  'No',
#  '4583',
#  '1508',
#  '128',
#  '360',
#  '1',
#  'Rural',
#  'N']

# %%
def create_item_dict(values, headers):
    result = {}
    for value, header in zip(values, headers):
       result[header] = value
    return result

# %%
# creating a dictionary that takes headers as keys and values1 as values
create_item_dict(values2, headers)
# Out:
# {'Loan_ID': 'LP001003',
#  'Gender': 'Male',
#  'Married': 'Yes',
#  'Dependents': '1',
#  'Education': 'Graduate',
#  'Self_Employed': 'No',
#  'ApplicantIncome': '4583',
#  'CoapplicantIncome': '1508',
#  'LoanAmount': '128',
#  'Loan_Amount_Term': '360',
#  'Credit_History': '1',
#  'Property_Area': 'Rural',
#  'Loan_Status': 'N'}

# %% [markdown]
# - As expected, the values & header are combined to create a dictionary with the approriate key-
# value pairs.
#
# - We are now ready to put it all together and define the read_csv function.

# %%
def read_csv(path):
    result = []
# Open the file in read mode
    with open(path, 'r') as f:
# Get a list of lines
      lines = f.readlines ()
# Parse the header
      headers = parse_headers(lines[0])
# Loop over the remaining lines
      for data_line in lines[1:]:
# Parse the values
          values = parse_values(data_line)
# Create a dictionary using values & headers
          item_dict = create_item_dict(values, headers)
# Add the dictionary to the result
          result.append(item_dict)
      return result

# %%
with open('./data_analytics/loan_train.csv') as file2:
     file2_contents = file2.read()

# %%
print(file2_contents)
# Out:
# Loan_ID,Gender,Married,Dependents,Education,Self_Employed,ApplicantIncome,CoapplicantIncome,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area,Loan_Status
# LP001002,Male,No,0,Graduate,No,5849,0,,360,1,Urban,Y
# LP001003,Male,Yes,1,Graduate,No,4583,1508,128,360,1,Rural,N
# LP001005,Male,Yes,0,Graduate,Yes,3000,0,66,360,1,Urban,Y
# LP001006,Male,Yes,0,Not Graduate,No,2583,2358,120,360,1,Urban,Y
# LP001008,Male,No,0,Graduate,No,6000,0,141,360,1,Urban,Y
# LP001011,Male,Yes,2,Graduate,Yes,5417,4196,267,360,1,Urban,Y
# LP001013,Male,Yes,0,Not Graduate,No,2333,1516,95,360,1,Urban,Y
# LP001014,Male,Yes,3+,Graduate,No,3036,2504,158,360,0,Semiurban,N
# LP001018,Male,Yes,2,Graduate,No,4006,1526,168,360,1,Urban,Y
# LP001020,Male,Yes,1,Graduate,No,12841,10968,349,360,1,Semiurban,N
# LP001024,Male,Yes,2,Graduate,No,3200,700,70,360,1,Urban,Y
# LP001027,Male,Yes,2,Graduate,,2500,1840,109,360,1,Urban,Y
# LP001028,Male,Yes,2,Graduate,No,3073,8106,200,360,1,Urban,Y
# ...

# %%
read_csv('./data_analytics/loan_train.csv')
# Out:
# [{'Loan_ID': 'LP001002',
#   'Gender': 'Male',
#   'Married': 'No',
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Self_Employed': 'No',
#   'ApplicantIncome': '5849',
#   'CoapplicantIncome': '0',
#   'LoanAmount': '',
#   'Loan_Amount_Term': '360',
#   'Credit_History': '1',
#   'Property_Area': 'Urban',
#   'Loan_Status': 'Y'},
#  {'Loan_ID': 'LP001003',
#   'Gender': 'Male',
#   'Married': 'Yes',
#   'Dependents': '1',
#   'Education': 'Graduate',
#   'Self_Employed': 'No',
#   'ApplicantIncome': '4583',
#   'CoapplicantIncome': '1508',
#   'LoanAmount': '128',
#   'Loan_Amount_Term': '360',
#   'Credit_History': '1',
#   'Property_Area': 'Rural',
#   'Loan_Status': 'N'},
#  {'Loan_ID': 'LP001005',
#   'Gender': 'Male',
#   'Married': 'Yes',
#   'Dependents': '0',
#   'Education': 'Graduate',
#   'Self_Employed': 'Yes',
#   'ApplicantIncome': '3000',
#   'CoapplicantIncome': '0',
#   'LoanAmount': '66',
#   'Loan_Amount_Term': '360',
#   'Credit_History': '1',
# ...
